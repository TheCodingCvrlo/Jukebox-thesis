# %% [markdown]
# <a href="https://colab.research.google.com/github/TheCodingCvrlo/bachelor-thesis/blob/main/flatten_data_structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Carlo Antonio Patti, 3134395
# ### Bocconi University, May 2023
# A notebook written in fulfillment of the requirements for the Degree of Bachelor of Science in Economics, Management and Computer Science

# %%
#@title Drive Mount
from google.colab import drive
drive.mount("drive", force_remount = True)
# Out:
# Mounted at drive

# %% [markdown]
# This notebook takes care of formatting the dataset in a more python-friendly structure. The hierarchical folder structure that the data originally comes in, is flattened to a simple CSV file.

# %%
#@title Imports
import os
import numpy as np
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
import pickle
from copy import Error
from copy import deepcopy as cp


#viz
import matplotlib.pyplot as plt
import seaborn as sns

#pytorch default imports
import torch
from torch import nn
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda

#llm
import spacy

# %%
PATH_REPS = "drive//MyDrive//thesis//data//representations"
PATH_RAW = "/content/drive/.shortcut-targets-by-id/1tfEM0F7Qg_pauab_tm1XrAU_QTWwSJwS/MP3_complete_done/"

# %%
def extract_data(FOLDER_PATH, verbose=False, exist_ok=False, have_reps=True):

  #extrapolate sample size
  n_rows = sum([len(os.listdir(os.path.join(FOLDER_PATH, artist_folder))) for artist_folder in os.listdir(FOLDER_PATH) if os.path.isdir(FOLDER_PATH+f'/{artist_folder}')])

  #standard jukebox output size
  n_features = 4800

  #allocate space in memory
  features = np.zeros((n_rows, n_features), dtype = np.float32) #might store in smaller dtype for memory efficiency


  labels = []
  titles = []
  #initialize counter to fill "features" array properly

  artists = [i for i in os.listdir(FOLDER_PATH) if os.path.isdir(FOLDER_PATH+f'/{i}')]
  row_counter = 0

  #loop over every artist folder
  for i in range(len(artists)):

    artist = artists[i]

    ARTIST_PATH = FOLDER_PATH + f'//{artist}'

    #fill in extracted vectors
    for song in os.listdir(ARTIST_PATH):

      title = ' - '.join(song.split(' - ')[1:]).replace('.mp3.npy','')

      PATH_SONG = ARTIST_PATH + f'//{song}'

      try:
        if have_reps:
          ff = np.extract(True, np.load(PATH_SONG, allow_pickle=True))[0][36]
          titles.append(song) #change to title if want clean title (no artist, no file extension)
          labels.append(artist)
          features[row_counter] = ff
          row_counter += 1
        else:
          titles.append(title)
          labels.append(artist)
          row_counter += 1


      except:
        print(f'failed to extract {song}') #corrupt files check
        row_counter += 1
        titles.append(title)
        labels.append(artist)

        continue


    if verbose:
      print(f"extracted folder: {artist}")

  if have_reps:
    return features, labels, titles

  else:
    return labels, titles

# %%
feats, labs, titls = extract_data(PATH_REPS, verbose=True)

ordenc = OrdinalEncoder()

df = pd.DataFrame(feats)
df['artist'] = labs
df['title'] = titls
df['label'] = ordenc.fit_transform(np.array(labs).reshape(-1,1))
df['label'] = df['label'].astype(int)
# Out:
# extracted folder: 10cc
# extracted folder: 2 Chainz
# extracted folder: 2Pac
# extracted folder: 3 Doors Down
# extracted folder: 38 Special
# extracted folder: 3OH!3
# extracted folder: 69 Boyz
# extracted folder: A Band Of Boys
# extracted folder: A Boy Called Joni
# extracted folder: A Perfect Circle
# extracted folder: A Tribe Called Quest
# extracted folder: A$AP Rocky
# extracted folder: A&G
# extracted folder: A.M
# extracted folder: ABBA
# extracted folder: ABC
# extracted folder: ACDC
# extracted folder: Aarian Pope
# extracted folder: Aaron Lewis
# extracted folder: Aaron Neville
# extracted folder: Aaron Tippin
# extracted folder: Absolutely Fabulous
# extracted folder: Ace Frehley
# extracted folder: Adam Ant
# extracted folder: Adam Lambert
# extracted folder: Aerosmith
# extracted folder: Aimee Mann
# extracted folder: Air Supply
# extracted folder: Al B. Sure!
# extracted folder: Al Green
# extracted folder: Al Hirt
# extracted folder: Al Jarreau
# extracted folder: Alabama
# extracted folder: Alan Jackson
# extracted folder: Alanis Morissette
# extracted folder: Alex Stealthy
# extracted folder: Alexander O'Neal
# extracted folder: Alias
# extracted folder: Alice Cooper
# extracted folder: Alice In Chains
# extracted folder: Alison Krauss
# extracted folder: Allman Brothers Band
# extracted folder: Ally Brooke
# extracted folder: America
# extracted folder: Ameritz Tribute Standards
# extracted folder: Amy Dorsey
# extracted folder: Ananya Bhat
# extracted folder: Anderson .Paak
# extracted folder: Andrea Bocelli
# extracted folder: Angelo De Augustine
# extracted folder: Anita Pointer
# extracted folder: Ankit Tiwari
# extracted folder: Ann-Margret
# extracted folder: Anne Briggs
# extracted folder: Anu Malik
# extracted folder: Arcade Fire
# extracted folder: Aretha Franklin
# extracted folder: Ariana Grande
# extracted folder: Arijit Singh
# extracted folder: Arlo Guthrie
# extracted folder: Armaan Malik
# extracted folder: Artimus Pyle
# extracted folder: Asha Bhosle
# extracted folder: Astrud Gilberto
# extracted folder: Atif Aslam
# extracted folder: Atlanta Rhythm Section
# extracted folder: Ayanis
# extracted folder: B-Brazy
# extracted folder: BTS
# extracted folder: Baby Tate
# extracted folder: Bad Company
# extracted folder: Badfinger
# extracted folder: Badwayz
# extracted folder: Bananarama
# extracted folder: Banyan Tree
# extracted folder: Barbra Streisand
# extracted folder: Barenaked Ladies
# extracted folder: Barnstorm
# extracted folder: Barry Manilow
# extracted folder: Barry White
# extracted folder: Basic Perspective
# extracted folder: Beastie Boys
# extracted folder: Bebe Rexha
# extracted folder: Beltek
# extracted folder: Bette Midler
# extracted folder: Beyoncé
# extracted folder: Big & Rich
# extracted folder: Big Audio Dynamite
# extracted folder: Big Boys
# extracted folder: Big Brother & The Holding Company
# extracted folder: Big Mountain
# extracted folder: Big _ Rich
# extracted folder: Biggie Smalls
# extracted folder: Bill Cosby
# extracted folder: Bill Graham
# extracted folder: Bill Hader
# extracted folder: Bill Medley
# extracted folder: Bill Miller
# extracted folder: Bill Withers
# extracted folder: Billy G-son
# extracted folder: Billy Idol
# extracted folder: Billy Ray Cyrus
# extracted folder: Bing Crosby
# extracted folder: Björk
# extracted folder: Black Eyed Peas
# extracted folder: Black Hippy
# extracted folder: Black M
# extracted folder: Black Oak Arkansas
# extracted folder: Black Sabbath
# extracted folder: Blackfoot feat. Ricky Medlocke
# extracted folder: Blake Shelton
# extracted folder: Blondie
# extracted folder: Bloodhound Gang
# extracted folder: Blue Öyster Cult
# extracted folder: Bob Dylan
# extracted folder: Bob Seger
# extracted folder: Bobby Angelo & The Tuxedos
# extracted folder: Bobby Hackett
# extracted folder: Bobby Vinton
# extracted folder: Bobby Womack
# extracted folder: Bon Iver
# extracted folder: Bone Thugs-N-Harmony
# extracted folder: Boney M
# extracted folder: Bonnie Raitt
# extracted folder: Boots Randolph
# extracted folder: Boz Scaggs
# extracted folder: Brad Paisley
# extracted folder: Brandy
# extracted folder: Brass Construction
# extracted folder: Brenda Lee
# extracted folder: Brian Courtney Wilson
# extracted folder: Brian Eno
# extracted folder: Brian Epstein
# extracted folder: Brian Wilson
# extracted folder: Bruce Springsteen
# extracted folder: Bryan Adams
# extracted folder: Buchanan Brothers
# extracted folder: Buckcherry
# extracted folder: Buddy Miller
# extracted folder: Buffalo Springfield
# extracted folder: Busta Rhymes
# extracted folder: C.F.O.P.A
# extracted folder: CAKE
# extracted folder: Calvin Harris
# extracted folder: Cam’ron
# extracted folder: Carl B
# extracted folder: Carly Simon
# extracted folder: Carpenters
# extracted folder: Cassidy
# extracted folder: Castro
# extracted folder: Cautious Clay
# extracted folder: Céline Dion
# extracted folder: ChainReaction
# extracted folder: Chaka Khan
# extracted folder: Change
# extracted folder: Charli XCX
# extracted folder: Charlie Puth
# extracted folder: Charme
# extracted folder: Cheap Trick
# extracted folder: Cheech & Chong
# extracted folder: Chicago
# extracted folder: Chief Okena Littlehawk
# extracted folder: Childish Gambino
# extracted folder: Chris Brown
# extracted folder: Chris Isaak
# extracted folder: Chris Jasper
# extracted folder: Chris Mars
# extracted folder: Christina Aguilera
# extracted folder: Chuck & Linda Sylvester
# extracted folder: Chuck Berry
# extracted folder: Cilla Fisher & Artie Trezise
# extracted folder: Clarence Carter
# extracted folder: Clouded Leopard
# extracted folder: Coi Leray
# extracted folder: Coldplay
# extracted folder: Collective Soul
# extracted folder: Collin Raye
# extracted folder: Commander Cody
# extracted folder: Commander Cody and His Lost Planet Airmen
# extracted folder: Commodores
# extracted folder: Corey Hart
# extracted folder: Cory Pesaturo
# extracted folder: Count Basie
# extracted folder: Crash Test Dummies
# extracted folder: Creedence Clearwater Revival
# extracted folder: Cressida
# extracted folder: Crimson & Folks
# extracted folder: Crispian St. Peters
# extracted folder: Crown Heights Affair
# extracted folder: Curtis Mayfield
# extracted folder: Curtis Stigers
# extracted folder: Cyndi Lauper
# extracted folder: Cypress Hill
# extracted folder: D'Alt Vila
# extracted folder: DEVO
# extracted folder: DJ Envy
# extracted folder: DJ Paul
# extracted folder: DJ Premier
# extracted folder: DMX
# extracted folder: Da Hood
# extracted folder: Da Shortiez
# extracted folder: Daddy Yankee
# extracted folder: Daft Punk
# extracted folder: Dan Rockett
# extracted folder: Daniel Rojas
# extracted folder: Daryl Hall & John Oates
# extracted folder: Dave Hollister
# extracted folder: Dave Matthews Band
# extracted folder: David Bowie
# extracted folder: David Bowie & The Spiders From Mars
# extracted folder: David Byrne
# extracted folder: David Gilmour
# extracted folder: David Guetta
# extracted folder: Davy Graham
# extracted folder: Daya
# extracted folder: Dead Prez
# extracted folder: Dean Martin
# extracted folder: Debbie Gibson
# extracted folder: Deep Purple
# extracted folder: Def Leppard
# extracted folder: Deliverance
# extracted folder: Deniece Williams
# extracted folder: Depeche Mode
# extracted folder: Derek & The Dominos
# extracted folder: Desti Musta
# extracted folder: Destiny's Child
# extracted folder: Diana Krall
# extracted folder: Diana Ross
# extracted folder: Diana Ross & The Supremes
# extracted folder: Dick Gaughan
# extracted folder: Dido
# extracted folder: Diedrich Bader
# extracted folder: Digital Underground
# extracted folder: Dire Straits
# extracted folder: Disturbed
# extracted folder: Dj Eremit
# extracted folder: Dokmai
# extracted folder: Dolly Parton
# extracted folder: Don Bryant
# extracted folder: Don Omar
# extracted folder: Don Williams
# extracted folder: Done Again
# extracted folder: Donell Jones
# extracted folder: Donna Summer
# extracted folder: Donovan
# extracted folder: Dr. Dre
# extracted folder: DragonForce
# extracted folder: Drake
# extracted folder: Drama Relax
# extracted folder: Duran Duran
# extracted folder: Dwight Yoakam
# extracted folder: ELO Part II
# extracted folder: ERNEST
# extracted folder: Earth, Wind _ Fire
# extracted folder: Ed Ames
# extracted folder: Ed Sheeran
# extracted folder: Eddie Money
# extracted folder: Eddy Arnold
# extracted folder: Ednita Nazario
# extracted folder: Elbow
# extracted folder: Electric Light Orchestra
# extracted folder: Electric Wurms
# extracted folder: Electro Prompt
# extracted folder: Ella Fitzgerald
# extracted folder: Elton John
# extracted folder: Elvis Costello
# extracted folder: Elvis Presley
# extracted folder: Eminem
# extracted folder: Emmylou Harris
# extracted folder: Emmylou Harris w Roy Orbison
# extracted folder: En Vogue
# extracted folder: Engelbert Humperdinck
# extracted folder: Enigma
# extracted folder: Enrique Iglesias
# extracted folder: Enya
# extracted folder: Erasure
# extracted folder: Eric Church
# extracted folder: Eric Clapton
# extracted folder: Eric Stewart
# extracted folder: Erykah Badu
# extracted folder: Es Vedrá
# extracted folder: Esha Gaur
# extracted folder: Estuera
# extracted folder: Europe
# extracted folder: Everclear
# extracted folder: Everlast
# extracted folder: Everything But The Girl
# extracted folder: Eydie Gormé
# extracted folder: Faces
# extracted folder: Faith Evans
# extracted folder: Fall Out Boy
# extracted folder: Fantasia
# extracted folder: Fat Boys
# extracted folder: Feist
# extracted folder: Fifth Harmony
# extracted folder: Flavor Flav
# extracted folder: Fleetwood Mac
# extracted folder: Florence + The Machine
# extracted folder: Floyd Cramer
# extracted folder: Focus
# extracted folder: Foghat
# extracted folder: Fonzerelli
# extracted folder: Foo Fighters
# extracted folder: Frank Ocean
# extracted folder: Frank Sinatra
# extracted folder: Frank Zappa
# extracted folder: Frankie Valli & The Four Seasons
# extracted folder: Frankie Valli _ The Four Seasons
# extracted folder: Frayser Boy
# extracted folder: Frehley's Comet
# extracted folder: French Montana
# extracted folder: Frida
# extracted folder: Frightened Rabbit
# extracted folder: Frost
# extracted folder: Fun Boy Three
# extracted folder: Future
# extracted folder: G Herbo
# extracted folder: GENERATIONS from EXILE TRIBE
# extracted folder: Gabrielle
# extracted folder: Garbage
# extracted folder: Gary Allan
# extracted folder: Gary Lewis & The Playboys
# extracted folder: Gary Numan
# extracted folder: Geeta Dutt
# extracted folder: Gene Loves Jezebel
# extracted folder: Gene Simmons
# extracted folder: Generation X
# extracted folder: Genesis
# extracted folder: George Benson
# extracted folder: George Duke
# extracted folder: George Harrison
# extracted folder: George Jones
# extracted folder: George Michael
# extracted folder: George Strait
# extracted folder: George Thorogood
# extracted folder: Gerbert
# extracted folder: Gino Vannelli
# extracted folder: Ginuwine
# extracted folder: Gladys Knight & The Pips
# extracted folder: Glen Ballard
# extracted folder: Glen Campbell
# extracted folder: Glenn Morrison
# extracted folder: Glenn Yarbrough
# extracted folder: Global Experience
# extracted folder: Gloria Estefan
# extracted folder: Godsmack
# extracted folder: Good Charlotte
# extracted folder: Gordon Lightfoot
# extracted folder: Gorillaz
# extracted folder: Grace Jones
# extracted folder: Graham Parker
# extracted folder: Grand Funk Railroad
# extracted folder: Grateful Dead
# extracted folder: Green Day
# extracted folder: Gretchen Wilson
# extracted folder: Gucci Mane
# extracted folder: Guns N' Roses
# extracted folder: H.E.R
# extracted folder: HEALTH
# extracted folder: Hank Williams, Jr
# extracted folder: Hannah Montana
# extracted folder: Haricharan
# extracted folder: Harold Melvin & The Blue Notes
# extracted folder: Harry Chapin
# extracted folder: Harry Nilsson
# extracted folder: Harry Styles
# extracted folder: Haystak
# extracted folder: Hembree
# extracted folder: Hensha
# extracted folder: Herb Alpert
# extracted folder: Hi-Lights
# extracted folder: Hilary Duff
# extracted folder: Hoo Bangin Gangsters
# extracted folder: Hozier
# extracted folder: Hugh Masekela
# extracted folder: Hunter Hayes
# extracted folder: Hypnotize Camp Posse
# extracted folder: ICEHOUSE
# extracted folder: ITA
# extracted folder: Ice Cube
# extracted folder: Idina Menzel
# extracted folder: Imagine Dragons
# extracted folder: Incubus
# extracted folder: India.Arie
# extracted folder: Indigo Girls
# extracted folder: Infectious Grooves
# extracted folder: Ingrid Michaelson
# extracted folder: Insane Clown Posse
# extracted folder: Isaac Hayes
# extracted folder: Italian Dire Straits
# extracted folder: J-Man
# extracted folder: J. Cole
# extracted folder: JES
# extracted folder: JPL
# extracted folder: JR JR
# extracted folder: JUVENILE
# extracted folder: JVKE
# extracted folder: Ja Rule
# extracted folder: Jack Jones
# extracted folder: Jackie Daly
# extracted folder: Jackson Browne
# extracted folder: Jagged Edge
# extracted folder: Jaheim
# extracted folder: Jake Owen
# extracted folder: James Blunt
# extracted folder: James Brown
# extracted folder: James Gang
# extracted folder: James Taylor
# extracted folder: Jamiroquai
# extracted folder: Jan & Dean
# extracted folder: Jane's Addiction
# extracted folder: Janet Jackson
# extracted folder: Janis Joplin
# extracted folder: Jarl Kulle
# extracted folder: Jars Of Clay
# extracted folder: Jasmine Guy
# extracted folder: Jason Derulo
# extracted folder: Jay & The Americans
# extracted folder: Jaytech
# extracted folder: Jean Knight
# extracted folder: Jedidja
# extracted folder: Jeezy
# extracted folder: Jeff Ament
# extracted folder: Jeff Foxworthy
# extracted folder: Jeff Waters
# extracted folder: Jefferson Airplane
# extracted folder: Jeffrey Osborne
# extracted folder: Jennifer Lopez
# extracted folder: Jerry Jeff Walker
# extracted folder: Jerry Keller
# extracted folder: Jerry Lee Lewis
# extracted folder: Jerry Reed
# extracted folder: Jerry Vale
# extracted folder: Jesse Fuller
# extracted folder: Jesse McCartney
# extracted folder: Jessi Colter
# extracted folder: Jessica Simpson
# extracted folder: Jesus Jones
# extracted folder: Jethro Tull
# extracted folder: Jewel
# extracted folder: Jill Scott
# extracted folder: Jim Jones
# extracted folder: Jim Morrison
# extracted folder: Jimi Hendrix
# extracted folder: Jimmy Buffett
# extracted folder: Jimmy Smith
# extracted folder: Jo Dee Messina
# extracted folder: JoJo
# extracted folder: Joan Armatrading
# extracted folder: Joan Baez
# extracted folder: Joan Jett & the Blackhearts
# extracted folder: Jodeci
# extracted folder: Joe
# extracted folder: John Anderson
# extracted folder: John Christian
# extracted folder: John Dahlbäck
# extracted folder: John Denver
# extracted folder: John Fogerty
# extracted folder: John Gary
# extracted folder: John Lee Hooker
# extracted folder: John Legend
# extracted folder: John Lennon
# extracted folder: John Mayall
# extracted folder: John Mayer
# extracted folder: John Mellencamp
# extracted folder: John Michael Montgomery
# extracted folder: John Sebastian
# extracted folder: John Tams
# extracted folder: John Williams
# extracted folder: Johnnie Taylor
# extracted folder: Johnny Cash
# extracted folder: Johnny Mathis
# extracted folder: Johnny Rivers
# extracted folder: Johnny Winter
# extracted folder: Jon B
# extracted folder: Jonas Steur
# extracted folder: Jones Jones
# extracted folder: Joni Mitchell
# extracted folder: Joseph Arthur
# extracted folder: José Feliciano
# extracted folder: Josh Kelley
# extracted folder: Journey
# extracted folder: Juanes
# extracted folder: Judas Priest
# extracted folder: Judy Collins
# extracted folder: Judy White
# extracted folder: Juicy J
# extracted folder: June Pointer
# extracted folder: June Tabor
# extracted folder: Justin Bieber
# extracted folder: Justin Timberlake
# extracted folder: K'Mac
# extracted folder: K. Michelle
# extracted folder: K. S. Chithra
# extracted folder: K.Flay
# extracted folder: KISS
# extracted folder: KRS-One
# extracted folder: KSHMR
# extracted folder: Kacey Musgraves
# extracted folder: Kamui
# extracted folder: Kansas
# extracted folder: Karen Overton
# extracted folder: Kate Bush
# extracted folder: Katy Perry
# extracted folder: Keane
# extracted folder: Keith Murray
# extracted folder: Keith Relf
# extracted folder: Keith Sweat
# extracted folder: Keith Urban
# extracted folder: Kelis
# extracted folder: Kelly Clarkson
# extracted folder: Kelly Rowland
# extracted folder: Kem
# extracted folder: KenTheMan
# extracted folder: Kendrick Lamar
# extracted folder: Kenny Chesney
# extracted folder: Kenny G
# extracted folder: Kenny Lattimore
# extracted folder: Kenny Loggins
# extracted folder: Kenny Rogers
# extracted folder: Kesha
# extracted folder: Kevin Gates
# extracted folder: Kevin Spacey
# extracted folder: Keyshia Cole
# extracted folder: Khalid
# extracted folder: Kid Cudi
# extracted folder: Kid Rock
# extracted folder: Kimito Lopez
# extracted folder: King Curtis
# extracted folder: King Unique
# extracted folder: Kings of Leon
# extracted folder: Kirk Franklin
# extracted folder: Kishore Kumar
# extracted folder: Kodak Black
# extracted folder: Kool & The Gang
# extracted folder: Kool John
# extracted folder: Korn
# extracted folder: Kozmic Blues Band
# extracted folder: Kris Kristofferson
# extracted folder: Krokus
# extracted folder: Kylie Minogue
# extracted folder: Lady A
# extracted folder: Lady Gaga
# extracted folder: Lakeside
# extracted folder: Lana Del Rey
# extracted folder: Larry Carlton
# extracted folder: Larry Graham & Graham Central Station
# extracted folder: Lata Mangeshkar
# extracted folder: Late Night Alumni
# extracted folder: Laurie London
# extracted folder: Lauv
# extracted folder: LeAnn Rimes
# extracted folder: Lecrae
# extracted folder: Led Zepagain
# extracted folder: Led Zeppelin
# extracted folder: Lee Ann Womack
# extracted folder: Lee Ritenour
# extracted folder: Lenny Kravitz
# extracted folder: Leo Birenberg & Zach Robinson
# extracted folder: Leo Birenberg _ Zach Robinson
# extracted folder: Leon & Mary Russell
# extracted folder: Leon Russell
# extracted folder: Leona Lewis
# extracted folder: Leonid Rudenko
# extracted folder: Leroy Holmes
# extracted folder: Lesley Gore
# extracted folder: Leslie Odom Jr
# extracted folder: Lifehouse
# extracted folder: Lil Durk
# extracted folder: Lil Jon
# extracted folder: Lil Wayne
# extracted folder: Lil Wyte
# extracted folder: Lil Yachty
# extracted folder: Lil' Flip
# extracted folder: Lil' Kim
# extracted folder: Lill-Babs
# extracted folder: Lily Allen
# extracted folder: Limp Bizkit
# extracted folder: Linda Ronstadt
# extracted folder: Linkin Park
# extracted folder: Lionel Richie
# extracted folder: Lisa Loeb
# extracted folder: Lisa Stansfield
# extracted folder: Little Mix
# extracted folder: Little Richard
# extracted folder: blink-182
# extracted folder: daydream Masi
# extracted folder: k.d. lang

# %%
labs_raw, titls_raw = extract_data(PATH_RAW, verbose=True, have_reps=False)

ordenc = OrdinalEncoder()

df_raw = pd.DataFrame()
df_raw['artist'] = labs_raw
df_raw['title'] = titls_raw
df_raw['label'] = ordenc.fit_transform(np.array(labs_raw).reshape(-1,1))
df_raw['label'] = df_raw['label'].astype(int)

# %%
PATH_CSV = "drive//MyDrive//thesis//data/representations.csv"
PATH_RAW_CSV = "drive//MyDrive//thesis//data/mp3_complete_flat.csv"
PATH_CSV_LONGTITLES = "drive//MyDrive//thesis//data/reps_longtitles.csv"

# %%
df.to_csv(PATH_CSV_LONGTITLE)

# %%
df_raw.to_csv(PATH_RAW_CSV)

# %% [markdown]
# Carlo Antonio Patti, Bocconi University, July 2023.
